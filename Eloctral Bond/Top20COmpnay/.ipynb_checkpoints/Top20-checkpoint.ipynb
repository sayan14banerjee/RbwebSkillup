# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('PurchaseData.csv')

# %%
df.head(10)
# Out:
#   Date of Purchase       Purchaser Name  Denomination
# 0        12-Apr-19  A B C INDIA LIMITED      100000.0
# 1        12-Apr-19  A B C INDIA LIMITED      100000.0
# 2        12-Apr-19  A B C INDIA LIMITED     1000000.0
# 3        12-Apr-19  A B C INDIA LIMITED     1000000.0
# 4        12-Apr-19  A B C INDIA LIMITED      100000.0
# 5        12-Apr-19  A B C INDIA LIMITED      100000.0
# 6        12-Apr-19  A B C INDIA LIMITED      100000.0
# 7        12-Apr-19  A B C INDIA LIMITED     1000000.0
# 8        12-Apr-19  A B C INDIA LIMITED      100000.0
# 9        12-Apr-19  A B C INDIA LIMITED      100000.0

# %%
grouped = df.groupby('Purchaser Name')['Denomination'].sum()

# %%
grouped
# Out:
# Purchaser Name
# 14 REELS PLUS LLP                      10000000.0
# A B C INDIA LIMITED                     4000000.0
# AAKANKSHA BAHETY                        1000000.0
# AALAYA CONSTRUCTIONS                   10000000.0
# AARISH SOLAR POWER PRIVATE LIMITED     20000000.0
#                                          ...
# YUVAN TRADING CONSULTANCY LLP          50000000.0
# ZENSAR TECHNOLOGIES LTD                30000000.0
# ZUVAN ENERGY PRIVATE LIMITED           10000000.0
# ZUVAN ENERGY PVT LTD                   20000000.0
# ZYDUS HEALTHCARE LIMITED              290000000.0
# Name: Denomination, Length: 1316, dtype: float64

# %%
top_20 = grouped.sort_values(ascending = False).head(20)

# %%
top_20
# Out:
# Purchaser Name
# FUTURE GAMING AND HOTEL SERVICES PR               1.208000e+10
# MEGHA ENGINEERING AND INFRASTRUCTURES LI MITED    8.210000e+09
# QWIKSUPPLYCHAINPRIVATELIMITED                     4.100000e+09
# HALDIA ENERGY LIMITED                             3.770000e+09
# VEDANTA LIMITED                                   3.756500e+09
# ESSEL MINING AND INDS LTD                         2.245000e+09
# WESTERN UP POWER TRANSMISSION COMPANY LI MITED    2.200000e+09
# KEVENTER FOODPARK INFRA LIMITED                   1.950000e+09
# MADANLAL LTD.                                     1.855000e+09
# BHARTI AIRTEL LIMITED                             1.830000e+09
# YASHODA SUPER SPECIALITY HOSPITAL                 1.620000e+09
# UTKAL ALUMINA INTERNATIONAL LIMITED               1.353000e+09
# DLF COMMERCIAL DEVELOPERS LIMITED                 1.300000e+09
# MKJ ENTERPRISES LIMITED                           1.283500e+09
# JINDAL STEEL AND POWER LIMITED                    1.230000e+09
# B G SHIRKE CONSTRUCTION TECHNOLOGY PVT L TD       1.170000e+09
# DHARIWAL INFRASTRUCTURE LIMITED                   1.150000e+09
# CHENNAI GREEN WOODS PRIVATE LIMITED               1.050000e+09
# BIRLACARBONINDIAPRIVATELIMITED                    1.050000e+09
# RUNGTA SONS P LTD                                 1.000000e+09
# Name: Denomination, dtype: float64

# %%
# Function to convert numbers to a shortened format
def shorten_number(number):
    if number >= 10**9:
        return f"{number // 10**9} bil"
    elif number >= 10**7:
        return f"{number // 10**7} cr"
    else:
        return number

top_20.plot(kind='bar', figsize=(10, 6))

for bar in bars:
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), 
             shorten_number(int(bar.get_height())), ha='center', va='bottom')

plt.title('Top 20 Purchasers by Total Denomination')
plt.xlabel('Purchaser Name')
plt.ylabel('Total Denomination')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
for Purchaser_name , Denomination in top_20.items():
    print("Purchaser Name:", Purchaser_name)
    print("Total Denomination:", Denomination)
# Out:
# Purchaser Name: FUTURE GAMING AND HOTEL SERVICES PR
# Total Denomination: 12080000000.0
# Purchaser Name: MEGHA ENGINEERING AND INFRASTRUCTURES LI MITED
# Total Denomination: 8210000000.0
# Purchaser Name: QWIKSUPPLYCHAINPRIVATELIMITED
# Total Denomination: 4100000000.0
# Purchaser Name: HALDIA ENERGY LIMITED
# Total Denomination: 3770000000.0
# Purchaser Name: VEDANTA LIMITED
# Total Denomination: 3756500000.0
# Purchaser Name: ESSEL MINING AND INDS LTD
# Total Denomination: 2245000000.0
# Purchaser Name: WESTERN UP POWER TRANSMISSION COMPANY LI MITED
# Total Denomination: 2200000000.0
# Purchaser Name: KEVENTER FOODPARK INFRA LIMITED
# Total Denomination: 1950000000.0
# Purchaser Name: MADANLAL LTD.
# Total Denomination: 1855000000.0
# Purchaser Name: BHARTI AIRTEL LIMITED
# Total Denomination: 1830000000.0
# Purchaser Name: YASHODA SUPER SPECIALITY HOSPITAL
# Total Denomination: 1620000000.0
# Purchaser Name: UTKAL ALUMINA INTERNATIONAL LIMITED
# Total Denomination: 1353000000.0
# Purchaser Name: DLF COMMERCIAL DEVELOPERS LIMITED
# Total Denomination: 1300000000.0
# Purchaser Name: MKJ ENTERPRISES LIMITED
# Total Denomination: 1283500000.0
# Purchaser Name: JINDAL STEEL AND POWER LIMITED
# Total Denomination: 1230000000.0
# Purchaser Name: B G SHIRKE CONSTRUCTION TECHNOLOGY PVT L TD
# Total Denomination: 1170000000.0
# Purchaser Name: DHARIWAL INFRASTRUCTURE LIMITED
# Total Denomination: 1150000000.0
# Purchaser Name: CHENNAI GREEN WOODS PRIVATE LIMITED
# Total Denomination: 1050000000.0
# Purchaser Name: BIRLACARBONINDIAPRIVATELIMITED
# Total Denomination: 1050000000.0
# Purchaser Name: RUNGTA SONS P LTD
# Total Denomination: 1000000000.0

# %%
top_20_names = top_20.index.tolist()
top_20_names
# Out:
# ['FUTURE GAMING AND HOTEL SERVICES PR',
#  'MEGHA ENGINEERING AND INFRASTRUCTURES LI MITED',
#  'QWIKSUPPLYCHAINPRIVATELIMITED',
#  'HALDIA ENERGY LIMITED',
#  'VEDANTA LIMITED',
#  'ESSEL MINING AND INDS LTD',
#  'WESTERN UP POWER TRANSMISSION COMPANY LI MITED',
#  'KEVENTER FOODPARK INFRA LIMITED',
#  'MADANLAL LTD.',
#  'BHARTI AIRTEL LIMITED',
#  'YASHODA SUPER SPECIALITY HOSPITAL',
#  'UTKAL ALUMINA INTERNATIONAL LIMITED',
#  'DLF COMMERCIAL DEVELOPERS LIMITED',
#  'MKJ ENTERPRISES LIMITED',
#  'JINDAL STEEL AND POWER LIMITED',
#  'B G SHIRKE CONSTRUCTION TECHNOLOGY PVT L TD',
#  'DHARIWAL INFRASTRUCTURE LIMITED',
#  'CHENNAI GREEN WOODS PRIVATE LIMITED',
#  'BIRLACARBONINDIAPRIVATELIMITED',
#  'RUNGTA SONS P LTD']

# %%
Top_20_Company= pd.DataFrame({'Purchaser Name': top_20_names})

# %%
Top_20_Company
# Out:
#                                     Purchaser Name                     CIN
# 0              FUTURE GAMING AND HOTEL SERVICES PR   U51901TZ1991PTC003583
# 1   MEGHA ENGINEERING AND INFRASTRUCTURES LI MITED   L45200TG2009PLC061324
# 2                    QWIKSUPPLYCHAINPRIVATELIMITED   U51100MH2000PTC129528
# 3                            HALDIA ENERGY LIMITED   L85110WB2007PLC129922
# 4                                  VEDANTA LIMITED   L13209MH1965PLC291394
# 5                        ESSEL MINING AND INDS LTD   U51109WB1950PLC018728
# 6   WESTERN UP POWER TRANSMISSION COMPANY LI MITED   U40105UP2009PLC038219
# 7                  KEVENTER FOODPARK INFRA LIMITED   U74999DL2011PLC218423
# 8                                    MADANLAL LTD.   L51909WB1983PLC036288
# 9                            BHARTI AIRTEL LIMITED   U74200MH2001PLC113726
# 10               YASHODA SUPER SPECIALITY HOSPITAL   U85110UP2019PTC160386
# 11             UTKAL ALUMINA INTERNATIONAL LIMITED   U24299OR2004PLC008001
# 12               DLF COMMERCIAL DEVELOPERS LIMITED   U70101DL2002PLC113636
# 13                         MKJ ENTERPRISES LIMITED   L65929MH2016PLC305800
# 14                  JINDAL STEEL AND POWER LIMITED   L27105HR1979PLC009913
# 15     B G SHIRKE CONSTRUCTION TECHNOLOGY PVT L TD   U45201PN1994PTC077340
# 16                 DHARIWAL INFRASTRUCTURE LIMITED   U70109WB2006PLC111457
# 17             CHENNAI GREEN WOODS PRIVATE LIMITED   U37100TN2022PTC156686
# 18                  BIRLACARBONINDIAPRIVATELIMITED   U23201MH2013PTC241741
# 19                               RUNGTA SONS P LTD   U02005WB1943PTC011231

# %%
Top_20_Company['CIN'] = ['U51901TZ1991PTC003583', 'L45200TG2009PLC061324', 'U51100MH2000PTC129528', 'L85110WB2007PLC129922', 'L13209MH1965PLC291394', 'U51109WB1950PLC018728', 'U40105UP2009PLC038219', 'U74999DL2011PLC218423', 'L51909WB1983PLC036288', 'U74200MH2001PLC113726', 'U85110UP2019PTC160386', 'U24299OR2004PLC008001', 'U70101DL2002PLC113636', 'L65929MH2016PLC305800',' L27105HR1979PLC009913', 'U45201PN1994PTC077340', 'U70109WB2006PLC111457', 'U37100TN2022PTC156686', 'U23201MH2013PTC241741', 'U02005WB1943PTC011231']

# %%
Top_20_Company['Date of registration'] =
